# %% [markdown]
# ## Identifiers and rules

# %%
x=5  #vaild indentifier

# %%
var1="welcome to python" #vaild identifier

# %%
_name="Keerthi"

# %% [markdown]
# ## Literals and its types

# %%
A='K' #character literal

# %%
name="Keerthi Reddy" #string literal
a=5 #numeric literal
b=10.2

# %%
K=2  #True is boolean literal
print(K==2)
# Out:
# True

# %%
var=None
print(var) #special literals
# Out:
# None

# %% [markdown]
# ## Opertors and its types

# %%
5+4 #5 and 4 are operand as we applying + operator on these numbers
# Out:
# 9

# %% [markdown]
# ## Arithmetic operator

# %%
5+1
# Out:
# 6

# %%
5-6
# Out:
# -1

# %%
5*6
# Out:
# 30

# %%
5/2
# Out:
# 2.5

# %%
5//2
# Out:
# 2

# %%
5//3
# Out:
# 1

# %%
5**3
# Out:
# 125

# %%
5**4
# Out:
# 625

# %%
5%4
# Out:
# 1

# %% [markdown]
# ### Assignment operator

# %%
x=5

# %%
x=x+1

# %%
x
# Out:
# 6

# %%
x+=3 #add

# %%
x
# Out:
# 9

# %%
x-=3  #sub
print(x)
# Out:
# 4

# %%
x*=2  
print(x)
# Out:
# 32

# %%
x/=2
print(x)
# Out:
# 16.0

# %%
x//=3
print(x)
# Out:
# 2.0

# %%
x**=2
print(x)
# Out:
# 4.0

# %% [markdown]
# ## Bitwise Operator

# %%
A=10 #1010      ##Bitwise &AND operator
B=4  #0100
A&B  #0000  #if both 1,then 1 else 0.
# Out:
# 0

# %%
#Binary of 10
#10/2=5 0
#5/2=2  1
#2/2=1  0
#1/2=0  1

# %%
#Binary of 12 = 1100
#12/2=6 0
#6/2=3  0
#3/2=1  1
#1/1=0  1

# %%
A=10  #Bitwise | OR operator
B=4
A|B
# Out:
# 14

# %%
#Binary to decimal
#1 1 1 0
#3 2 1 0

1*(2**3)+1*(2**2)+1*(2**1)+0*(2**0)
# Out:
# 14

# %%
A=10  ##Biwise ~ NOT Operator
~A
# Out:
# -11

# %%
A=10  ##Bitwise^XOR Operator
B=4
A^B
# Out:
# 14

# %%
A=10  ##leftshift operator
A>>3
# Out:
# 1

# %%
A=10  ##Rightshift operator
A<<3
# Out:
# 80

# %% [markdown]
# ## Comparision Operator

# %%
A=2
B=4
A==B
# Out:
# False

# %%
A<=B
# Out:
# True

# %%
A>=B
# Out:
# False

# %% [markdown]
# ## Identity Operator

# %%
x=10  ##Is operator
y=10
x is y
# Out:
# True

# %%
x=8
y=10
x is y
# Out:
# False

# %%
x is not y  ## Is Not OPerator
# Out:
# True

# %% [markdown]
# ## Membership Operator

# %%
X="Keerthi"  ##In opertor
"K" in X
# Out:
# True

# %%
"S" not in X
# Out:
# True

# %%
"i" not in X ##not in Operator
# Out:
# False
